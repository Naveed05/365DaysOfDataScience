# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open(r"C:\Users\mirza\Downloads\naveed.jpg")
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open(r"C:\Users\mirza\Downloads\naveed_hostel.jpg")
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
type(img)
img_arr = np.asarray(img)
img_arr
# Out:
# array([[[219, 216, 223],
#         [219, 216, 223],
#         [219, 217, 222],
#         ...,
#         [192, 185, 193],
#         [195, 188, 196],
#         [188, 181, 189]],
#
#        [[218, 216, 221],
#         [218, 216, 221],
#         [218, 216, 221],
#         ...,
#         [195, 188, 196],
#         [198, 191, 199],
#         [188, 181, 189]],
#
#        [[218, 216, 221],
#         [218, 216, 221],
#         [218, 216, 221],
#         ...,
#         [197, 190, 198],
#         [194, 186, 197],
#         [187, 179, 190]],
#
#        ...,
#
#        [[ 34,  33,  31],
#         [ 36,  32,  31],
#         [ 36,  32,  31],
#         ...,
#         [ 48,  44,  43],
#         [ 45,  39,  39],
#         [ 45,  39,  39]],
#
#        [[ 35,  33,  34],
#         [ 34,  33,  31],
#         [ 36,  32,  31],
#         ...,
#         [ 42,  38,  35],
#         [ 40,  35,  32],
#         [ 52,  43,  44]],
#
#        [[ 34,  32,  33],
#         [ 34,  32,  33],
#         [ 36,  32,  33],
#         ...,
#         [ 44,  40,  37],
#         [ 45,  40,  37],
#         [ 56,  47,  48]]], dtype=uint8)
